# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('healthexp')
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df_us = df[df['Country'] =='USA']
plt.plot(df_us['Year'], df_us['Life_Expectancy'])
plt.show()

# %%
df_fr = df[df['Country'] == 'France']
plt.plot(df_fr['Year'], df_fr['Life_Expectancy'])
plt.plot(df_us['Year'], df_us['Life_Expectancy'])
plt.show()

# %%
plt.plot(df_fr['Year'], df_fr['Life_Expectancy'], label = 'France')
plt.plot(df_us['Year'], df_us['Life_Expectancy'], label = 'USA')
plt.legend()
plt.title('Life expectancy throughout the years')
plt.xlabel('Year')
plt.ylabel('Life expectancy (in years)')
plt.show()

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Horizontally stacked subplots')
axs[0].plot(df_fr['Year'], df_fr['Life_Expectancy'])
axs[0].set_title('France')
axs[1].plot(df_us['Year'], df_us['Life_Expectancy'])
axs[1].set_title('USA')
plt.tight_layout() 
plt.show()

# %%
fig,axs = plt.subplots(1,2)
fig.suptitle('Horizontally stacked subplots')
axs[0].plot(df_fr['Year'],df_fr["Life_Expectancy"])
axs[0].set_title('France')
axs[0].set_ylim(70,85)
axs[1].plot(df_us['Year'],df_us["Life_Expectancy"])
axs[1].set_title('USA')
axs[1].set_ylim(70,85)
# Out:
# (70.0, 85.0)

# %%
df_gb = df[df['Country'] == 'Great Britain']
df_ja = df[df['Country'] == 'Japan']
fig , axs = plt.subplots(2,2)
fig.suptitle('Horizontally stacked subplots')
axs[0,0].plot(df_fr['Year'],df_fr['Life_Expectancy'])
axs[0,0].set_title('France')
axs[0,1].plot(df_us['Year'],df_us['Life_Expectancy'])
axs[0,1].set_title('USA')
axs[1,0].plot(df_gb['Year'],df_gb['Life_Expectancy'])
axs[1,0].set_title('Great Britain')
axs[1,1].plot(df_ja['Year'],df_ja['Life_Expectancy'])
axs[1,1].set_title('Japan')
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=df,x = 'Year', y='Life_Expectancy',hue='Country')
plt.show()

# %%
sns.lineplot(data=df, x = 'Year' , y='Life_Expectancy', errorbar='sd')
plt.show()

# %% [markdown]
# **Task 1.1.1**

# %%
sns.lineplot(data=df, x = 'Year' , y='Life_Expectancy', errorbar='ci')
plt.show()

# %%
europe = ['Germany', 'France', 'Great Britain']
other = ['Japan', 'USA', 'Canada']
df.loc[df['Country'].isin(europe),'Continent'] = 'Europe'
df.loc[df['Country'].isin(other),'Continent'] = 'Other'
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy Continent
# 0    1970        Germany       252.311             70.6    Europe
# 1    1970         France       192.143             72.2    Europe
# 2    1970  Great Britain       123.993             71.9    Europe
# 3    1970          Japan       150.437             72.0     Other
# 4    1970            USA       326.961             70.9     Other
# ..    ...            ...           ...              ...       ...
# 269  2020        Germany      6938.983             81.1    Europe
# 270  2020         France      5468.418             82.3    Europe
# 271  2020  Great Britain      5018.700             80.4    Europe
# 272  2020          Japan      4665.641             84.7     Other
# 273  2020            USA     11859.179             77.0     Other
#
# [274 rows x 5 columns]

# %%
sns.lineplot(data = df, x='Year' ,y='Life_Expectancy',hue='Continent',errorbar='sd')
plt.show()

# %% [markdown]
# **Task 1.1.2**

# %%
fig,axs = plt.subplots(1,2)
sns.lineplot(data = df[df['Continent']=='Europe'], x='Year' ,y='Life_Expectancy',errorbar='sd',ax=axs[0])
axs[0].set_title('Europe')
sns.lineplot(data = df[df['Continent'] == 'Other'], x='Year' ,y='Life_Expectancy',errorbar='sd',ax=axs[1])
axs[1].set_title('Other')
plt.show()

# %%
df = pd.read_csv('../Lab2/penguins_modified_CLEAN.csv')
df
# Out:
#       ID species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      0  Adelie  Torgersen            39.1           18.7              181.0
# 1      1  Adelie  Torgersen            39.5           17.4              186.0
# 2      2  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen            36.7           19.3              193.0
# 4      5  Adelie  Torgersen            39.3           20.6              190.0
# ..   ...     ...        ...             ...            ...                ...
# 337  338  Gentoo     Biscoe            47.2           13.7              214.0
# 338  340  Gentoo     Biscoe            46.8           14.3              215.0
# 339  341  Gentoo     Biscoe            50.4           15.7              222.0
# 340  342  Gentoo     Biscoe            45.2           14.8              212.0
# 341  343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  bill_ratio
# 0         3750.0    Male    0.478261
# 1         3800.0  Female    0.440506
# 2         3250.0  Female    0.446650
# 3         3450.0  Female    0.525886
# 4         3650.0    Male    0.524173
# ..           ...     ...         ...
# 337       4925.0  Female    0.290254
# 338       4850.0  Female    0.305556
# 339       5750.0    Male    0.311508
# 340       5200.0  Female    0.327434
# 341       5400.0    Male    0.322645
#
# [342 rows x 9 columns]

# %%
df_ad= df[df['species']=='Adelie']
df_ge = df[df["species"]=='Gentoo']
plt.scatter(df_ad['bill_length_mm'],df_ad['bill_depth_mm'],label ='Adelie')
plt.scatter(df_ge['bill_length_mm'],df_ge['bill_depth_mm'],label ='Gentoo')
plt.legend()
plt.xlabel('Bill length (mm)')
plt.ylabel('Bill depth (mm)')
plt.show()

# %%
sns.scatterplot(data=df,x='bill_length_mm',y='bill_depth_mm',hue='species')
plt.show()

# %%
sns.scatterplot(data=df,x='bill_length_mm',y='bill_depth_mm',hue='species',style='species',palette='colorblind')
plt.show()

# %%
sns.scatterplot(data=df, x = 'bill_length_mm',y='bill_depth_mm',hue='species',size='body_mass_g',sizes=(20,200))
plt.legend(bbox_to_anchor =(1.02,1),loc='upper left', borderaxespad=0)
plt.show()

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='body_mass_g')
plt.show()

# %%
figure = sns.lmplot(data=df,x = 'bill_depth_mm',y = 'body_mass_g',hue = 'species')
plt.xlabel('Bill depth (mm)')
plt.ylabel('Body mass (g)')
figure._legend.set_title('Species')
plt.show()

# %% [markdown]
# **Task 1.2.1**

# %%
figure_island = sns.lmplot(data=df , x ='bill_length_mm', y = 'flipper_length_mm',hue='island')
plt.xlabel('Bill length (mm)')
plt.ylabel('Flipper length (mm)')
figure_island._legend.set_title('Island')
plt.show()

# %%
plt.bar(df['species'],df['body_mass_g'])
plt.xlabel('Species')
plt.ylabel('Body_mass_g')
plt.show()

# %%
sns.barplot(data=df,x ="species",y='body_mass_g')
plt.show()

# %%
sns.barplot(data = df,x='island',y='body_mass_g',hue='sex')
plt.show()

# %% [markdown]
# **Task 1.3.1**

# %%
sns.barplot(data = df,x='island',y='body_mass_g',hue='sex',ci='sd')
plt.show()
# Out:
# /Users/jinhaitao/opt/anaconda3/envs/mle_tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   """Entry point for launching an IPython kernel.

# %%
plt.hist(df['species'])
plt.show()

# %%
sns.histplot(data=df,x='species',hue='sex',multiple='dodge')
plt.show()

# %% [markdown]
# **Task 1.4.1**

# %%
sns.histplot(data=df,x='species',hue='sex',multiple='dodge',stat='percent')
plt.show()

# %%
sns.histplot(data=df,x='body_mass_g',hue='species')
plt.show()

# %%
sns.histplot(data=df,x='body_mass_g',hue='species',bins=24)
plt.show()

# %%
sns.kdeplot(data=df,x='body_mass_g',hue='species',fill=True)
plt.show()

# %%
sns.histplot(data=df, x='species',y='island',cbar=True)
plt.show()

# %%
plt.boxplot(df['body_mass_g'].dropna())
plt.ylabel('Body mass (g)')
plt.show()

# %%
sns.boxplot(data=df,x='species',y='body_mass_g')
plt.show()

# %%
sns.boxplot(data=df,x='species',y='body_mass_g',hue='sex')
plt.show()

# %% [markdown]
# **Task 1.5.1**

# %%
sns.boxplot(data=df,x='sex',y='flipper_length_mm',hue='species')
plt.show()

# %%
sns.violinplot(data=df,x='species',y='body_mass_g',hue='sex')
plt.show()

# %%
# %matplotlib inline

# %%
sns.violinplot(data=df,x='species',y='body_mass_g',hue='sex')
plt.savefig('violin_plot.png')

# %%
df_ao = pd.read_csv('/Users/jinhaitao/Desktop/input/2023_analyse_ourselves.csv')
df_ao
# Out:
#       ID           Start time      Completion time I love  Age Band  \
# 0      1  2023-01-31 13:05:06  2023-01-31 13:05:52   Dogs  18 to 24
# 1      2  2023-01-31 16:12:13  2023-01-31 16:14:24   Cats  18 to 24
# 2      3  2023-01-31 16:29:12  2023-01-31 16:30:16   Both  18 to 24
# 3      4  2023-01-31 17:18:53  2023-01-31 17:20:40   Both  18 to 24
# 4      5  2023-01-31 17:39:18  2023-01-31 17:40:34   Both  18 to 24
# ..   ...                  ...                  ...    ...       ...
# 187  202  2023-02-03 15:55:08  2023-02-03 15:56:30   Cats  18 to 24
# 188  203  2023-02-03 18:22:25  2023-02-03 18:23:26   Dogs  18 to 24
# 189  204  2023-02-05 19:06:06  2023-02-05 19:08:23   Cats  25 to 30
# 190  205  2023-02-06 11:44:38  2023-02-06 11:45:41   Both  18 to 24
# 191  206  2023-02-06 14:03:46  2023-02-06 14:05:31   Cats  18 to 24
#
#             Loving Marmite                      DMA motivation  \
# 0                      Yes  Increase knowledge of subject area
# 1                       No  Increase knowledge of subject area
# 2    Don't know what it is                        Just curious
# 3    Don't know what it is  Increase knowledge of subject area
# 4                       No  Increase knowledge of subject area
# ..                     ...                                 ...
# 187  Don't know what it is             Relevant to my research
# 188         Never tried it                        Just curious
# 189  Don't know what it is  Increase knowledge of subject area
# 190  Don't know what it is           Improve job opportunities
# 191  Don't know what it is             Relevant to my research
#
#     Optimistic about future           Favourite movie Feeling today  \
# 0            Strongly Agree  The Shawshank Redemption       Excited
# 1            Strongly Agree  The Shawshank Redemption         Tired
# 2                     Agree              Pulp Fiction         Tired
# 3                     Agree         None of the above           Sad
# 4                     Agree         None of the above       Excited
# ..                      ...                       ...           ...
# 187                 Neutral          Enter the Dragon         Tired
# 188          Strongly Agree          Star Wars (1977)       Excited
# 189          Strongly Agree  The Shawshank Redemption         Tired
# 190          Strongly Agree         None of the above       Excited
# 191                Disagree         None of the above       Anxious
#
#        Way to relax  Hours of sleep  Number of sweets  Completion duration  \
# 0       Gym workout             8.0               7.0                 46.0
# 1            Gaming             8.0              35.0                131.0
# 2      Bath and Bed             NaN               1.0                 64.0
# 3      Bath and Bed             7.0               3.0                107.0
# 4            Gaming             7.5              25.0                 76.0
# ..              ...             ...               ...                  ...
# 187          Gaming             7.0              10.0                 82.0
# 188  Reading a book             7.0              50.0                 61.0
# 189    Bath and Bed             7.0               6.0                137.0
# 190     Gym workout             6.0               NaN                 63.0
# 191          Gaming             8.0               8.0                105.0
#
#      Standardised hours of sleep
# 0                       0.714737
# 1                       0.714737
# 2                            NaN
# 3                      -0.133653
# 4                       0.290542
# ..                           ...
# 187                    -0.133653
# 188                    -0.133653
# 189                    -0.133653
# 190                    -0.982043
# 191                     0.714737
#
# [192 rows x 15 columns]

# %% [markdown]
# **Final Task 1**

# %%
df_ao.loc[df_ao['Optimistic about future'].str.contains('isagree'),'Optimistic about fture'] = 'Disagree'
df_ao.loc[df_ao['Optimistic about future'].str.contains('Strongly Agree'),'Optimistic about future'] = 'Agree'

# %% [markdown]
# **Final Task 2**

# %%
sns.histplot(data=df_ao,x= 'Optimistic about future')
plt.show()

# %% [markdown]
# **Final Task 3**

# %%
sns.barplot(data=df_ao,x='I love',y='Hours of sleep',errorbar='sd')
plt.show()

# %% [markdown]
# **Final Task 4

# %%
sns.scatterplot(data=df_ao,x ='Hours of sleep',y='Number of sweets')
plt.show()
sns.lmplot(data=df_ao,x='Hours of sleep',y='Number of sweets')
plt.show()

# %% [markdown]
# **Final Task 5**

# %%
sns.histplot(data=df_ao, x='Feeling today', hue='Optimistic about future', multiple='dodge', fill=True)
plt.show()

# %%
sns.boxplot(data=df_ao, x='I love', y='Hours of sleep')
plt.show()
sns.violinplot(data=df_ao, x='I love', y='Hours of sleep')
plt.show()
sns.kdeplot(data=df_ao, x='Hours of sleep', hue='I love', fill=True)
plt.show()
